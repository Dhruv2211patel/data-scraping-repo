# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv2211patel/my-first-repo/blob/master/webscaping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib import request
from bs4 import BeautifulSoup

# pointing to URL
url='https://en.wikipedia.org/wiki/Machine_learning'
url1='https://www.google.com/covid19/'

htmldata=request.urlopen(url1)
#htmldata.read()
soupdata=BeautifulSoup(htmldata,'html5lib')
atagdata=soupdata.findAll('p')
import time
mydata=""
for i in atagdata:
  mydata += i.text

  print(mydata)

 #print(atagdata)
# Out:
# Jump to Content
# Jump to ContentJump to Content
# Jump to ContentJump to Content
#
#
# Jump to ContentJump to Content
#
#
#                       General public health information
#
# Jump to ContentJump to Content
#
#
#                       General public health information
#                     Vox Media
# Jump to ContentJump to Content
#
#
#                       General public health information
#                     Vox MediaWorld Health Organization
# Jump to ContentJump to Content
#
#
#                       General public health information
#                     Vox MediaWorld Health OrganizationCenters for Disease Control and Prevention
# Jump to ContentJump to Content
#
#
#                       General public health information
#                     Vox MediaWorld Health OrganizationCenters for Disease Control and PreventionCenters for Disease Control and Prevention
# Jump to ContentJump to Content
#
#
#                       General public health information
# ...

# %%
import time 
for i in atagdata:
  print(i.text)
# Out:
# html5lib
# ERROR! Session/line number was not unique in database. History logging moved to new session 60

# %%
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# html5lib
